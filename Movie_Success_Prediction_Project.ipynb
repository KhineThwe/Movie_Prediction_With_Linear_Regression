# %% [markdown]
# ## Linear Regression Algorithm

# %%
import math
import matplotlib.pyplot as plt
def correlation_cof(size_of_data,sum_of_xy,sum_of_x,sum_of_y,sum_of_xS,sum_of_yS):
    r1 = size_of_data*sum_of_xy - sum_of_x*sum_of_y
    r2 = size_of_data*sum_of_xS - sum_of_x*sum_of_x
    r3 = size_of_data*sum_of_yS - sum_of_y*sum_of_y
    r2 = r2 * r3
    r2 = math.sqrt(r2)
    corre_cof = r1/r2
    if corre_cof > 0.97:
        print("Correlation Coefficient is near 1 ",corre_cof)
    else:
        print(corre_cof)

def b(sum_of_y,slope_m,sum_of_x,size_of_data):
    b1 = sum_of_y - slope_m*sum_of_x
    b = b1/size_of_data
    print("value of b",b)
    
x = [1,2,3,4,5,6,7]
y=[1.5,3.8,6.7,9.0,11.2,13,6,16]
sum_of_x = 28
sum_of_y = 61.8
sum_of_xy = 314.8
sum_of_xS = 140
sum_of_yS = 708.98
size_of_data = 7

#slope , y = mx+b
m1 = size_of_data*sum_of_xy - sum_of_x*sum_of_y
m2 = size_of_data*sum_of_xS - sum_of_x*sum_of_x
slope_m = m1/m2
print("*********************************")
print("Slope value is ",slope_m)
b(sum_of_y,slope_m,sum_of_x,size_of_data)
correlation_cof(size_of_data,sum_of_xy,sum_of_x,sum_of_y,sum_of_xS,sum_of_yS)
print("*********************************")
# Out:
# *********************************
# Slope value is  2.4142857142857146
# value of b -0.8285714285714302
# Correlation Coefficient is near 1  0.999483961218998
# *********************************

# %% [markdown]
# ## Requirements of Data Science Project

# %%
0.Identity Problem Statement
1.Data Gathering
2.Data Cleaning
3.Modeling (using Machine learning algorithm in our project)
4.Data Evaluating and Visualization(Visualization means plotting data with graph etc)
5.Data analysis(Check data resulted from machine learning algorithm is right or wrong)

List of Popular Machine Learning Algorithm

1. Linear Regression Linear regression is one of the most popular and simple machine learning algorithms that is used for predictive analysis. ...
2. Logistic Regression Logistic regression is the supervised learning algorithm, which is used to predict the categorical variables or discrete values. ...
3. Decision Tree Algorithm ...
4. Support Vector Machine Algorithm ...
5. Naïve Bayes Algorithm: ...
6. K-Nearest Neighbour (KNN) ...

# %% [markdown]
# ## Movie Data Project

# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

data = pd.read_csv('movie_data.csv')

data = data.replace([np.inf, -np.inf], np.nan)
data = data.dropna()
data = data.reset_index()
X = DataFrame(data,columns=['budget'])
y = DataFrame(data,columns=['gross'])
plt.scatter(x=X,y=y,alpha=1)

plt.title("Title: Budget and Gross")
plt.xlabel("Budget")
plt.ylabel("Gross")
plt.ylim(0,800000000)#million 0 8 lone#limits y axis range
plt.xlim(0,400000000)#million#limits x axis range

model = LinearRegression()#Linear regression model
model.fit(X,y)#x y two parameters

plt.plot(y,model.predict(y),color='red',linewidth=3)

print("coe",model.coef_)#m value
print("intercept",model.intercept_)#b value
print("r",model.score(X,y))

#Analysis
#y  = mx +b
#y = 1.04999162* 200000000+ 12005242.9035392
#33,005,075.3035392 #30 million gross= profit
# probability = 0.42 / 42% 
plt.show()
# Out:
# coe [[1.04999162]]
# intercept [12005242.9035392]
# r 0.4176192800553473

# %% [markdown]
# ## With Cleaned Data Set

# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# import warnings filter
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)

data = pd.read_csv('cleaned_movie_data.csv')

X = DataFrame(data,columns=['budget'])
y = DataFrame(data,columns=['gross'])
plt.scatter(x=X,y=y,alpha=1)

plt.title("Title: Budget and Gross")
plt.xlabel("Budget")
plt.ylabel("Gross")
plt.ylim(0,800000000)#80 million 0 8 lone#limits y axis range
plt.xlim(0,400000000)#40 million#limits x axis range

model = LinearRegression()#Linear regression model
model.fit(X,y)#x y two parameters

plt.plot(y,model.predict(y),color='red',linewidth=3)

print("coe",model.coef_)#m value
print("intercept",model.intercept_)#b value
print("r",model.score(X,y))

#Analysis
#y  = mx +b
#y = 0.85690257* 200000000+ 12875380.39735276
#30,013,431.79735276 #30 million gross= profit
# probability = 0.33 / 32% 

#Drawback of linear regression
#Linear မျဉ်းနားမှာရှိတဲ့ dataတွေသာ ပို မို မှန် ကန်သောကြော င့် ဖြစ်သည်။
plt.show()
# Out:
# coe [[0.85690257]]
# intercept [12875380.39735276]
# r 0.3264225250394184

# %% [markdown]
# ## Evaluating and Visualization Data

# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# import warnings filter
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)

data = pd.read_csv('cleaned_movie_data.csv')
plt.style.use("fivethirtyeight")

X = DataFrame(data,columns=['budget'])
y = DataFrame(data,columns=['gross'])
plt.scatter(x=X,y=y,alpha=1)

plt.title("Title: Budget and Gross")
plt.xlabel("Budget")
plt.ylabel("Gross")
plt.ylim(0,800000000)#80 million 0 8 lone#limits y axis range
plt.xlim(0,400000000)#40 million#limits x axis range

model = LinearRegression()#Linear regression model
model.fit(X,y)#x y two parameters

plt.plot(y,model.predict(y),color='red',linewidth=3)

print("coe",model.coef_)#m value
print("intercept",model.intercept_)#b value
print("r",model.score(X,y))

#Analysis
#y  = mx +b
#y = 0.85690257* 200000000+ 12875380.39735276
#30,013,431.79735276 #30 million gross= profit
# probability = 0.33 / 32% 

#Drawback of linear regression
#Linear မျဉ်းနားမှာရှိတဲ့ dataတွေသာ ပို မို မှန် ကန်သောကြော င့် ဖြစ်သည်။

plt.figure(figsize=(10,6))
plt.show()
# Out:
# coe [[0.85690257]]
# intercept [12875380.39735276]
# r 0.3264225250394184

# %% [markdown]
# ## Movie Project

# %%
# Imports and setup
import pandas as pd
import numpy as np
import scipy as sc
import seaborn as sns

#for dataset
#https://www.kaggle.com/datasets/gan2gan/1000-imdb-movies-20062016

# %% [markdown]
# ## Loading Data

# %%
# Loading the movies dataset into df1 and printing it to show the result.
df1 = pd.read_csv("IMDB-Movie-Data.csv")
display(df1.head(5))
# df1.shape# Row col
# df1.info() #checking
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %% [markdown]
# ## Checking missing values

# %%
#checking missing values in the dataset
print("Any Missing values? ",df1.isnull().values.any())
df1.isnull()
sns.heatmap(df1.isnull())

per_missing = df1.isnull().sum()*100/len(data)
per_missing
# Out:
# Any Missing values?  True
# Rank                  0.000000
# Title                 0.000000
# Genre                 0.000000
# Description           0.000000
# Director              0.000000
# Actors                0.000000
# Year                  0.000000
# Runtime (Minutes)     0.000000
# Rating                0.000000
# Votes                 0.000000
# Revenue (Millions)    2.921041
# Metascore             1.460520
# dtype: float64

# %% [markdown]
# ## Drop All the missing values

# %%
df1.dropna(axis=0)
# Out:
#                                     movie_title  ...                                    movie_imdb_link
# 0                                       Avatar   ...  http://www.imdb.com/title/tt0499549/?ref_=fn_t...
# 1     Pirates of the Caribbean: At World's End   ...  http://www.imdb.com/title/tt0449088/?ref_=fn_t...
# 2                                      Spectre   ...  http://www.imdb.com/title/tt2379713/?ref_=fn_t...
# 3                        The Dark Knight Rises   ...  http://www.imdb.com/title/tt1345836/?ref_=fn_t...
# 5                                  John Carter   ...  http://www.imdb.com/title/tt0401729/?ref_=fn_t...
# ...                                         ...  ...                                                ...
# 5026                                     Clean   ...  http://www.imdb.com/title/tt0388838/?ref_=fn_t...
# 5027                                The Circle   ...  http://www.imdb.com/title/tt0255094/?ref_=fn_t...
# ...

# %% [markdown]
# ## Check for duplicate data

# %%
dup_data = df1.duplicated().any()
print("Are there any duplicate values? ",dup_data)

df1 = df1.drop_duplicates()
df1
# Out:
# Are there any duplicate values?  False
#      Rank                    Title  ... Revenue (Millions) Metascore
# 0       1  Guardians of the Galaxy  ...             333.13      76.0
# 1       2               Prometheus  ...             126.46      65.0
# 2       3                    Split  ...             138.12      62.0
# 3       4                     Sing  ...             270.32      59.0
# 4       5            Suicide Squad  ...             325.02      40.0
# ..    ...                      ...  ...                ...       ...
# 995   996     Secret in Their Eyes  ...                NaN      45.0
# 996   997          Hostel: Part II  ...              17.54      46.0
# 997   998   Step Up 2: The Streets  ...              58.01      50.0
# 998   999             Search Party  ...                NaN      22.0
# 999  1000               Nine Lives  ...              19.64      11.0
#
# [1000 rows x 12 columns]

# %% [markdown]
# ## Get Overall Statistics About the dataframe

# %%
df1.describe(include='all')
# Out:
#                Rank     Title  ... Revenue (Millions)   Metascore
# count   1000.000000      1000  ...         872.000000  936.000000
# unique          NaN       999  ...                NaN         NaN
# top             NaN  The Host  ...                NaN         NaN
# freq            NaN         2  ...                NaN         NaN
# mean     500.500000       NaN  ...          82.956376   58.985043
# std      288.819436       NaN  ...         103.253540   17.194757
# min        1.000000       NaN  ...           0.000000   11.000000
# 25%      250.750000       NaN  ...          13.270000   47.000000
# 50%      500.500000       NaN  ...          47.985000   59.500000
# 75%      750.250000       NaN  ...         113.715000   72.000000
# max     1000.000000       NaN  ...         936.630000  100.000000
#
# [11 rows x 12 columns]

# %% [markdown]
# ## Display title of the movie having runtime >= 180 Minutes

# %%
df1.columns

df1[df1['Runtime (Minutes)'] >= 180]['Title']
# Out:
# 82     The Wolf of Wall Street
# 88           The Hateful Eight
# 311             La vie d'Adèle
# 828                 Grindhouse
# 965              Inland Empire
# Name: Title, dtype: object

# %% [markdown]
# ## In which year there was the highest average voting

# %%
df1.columns

df1.groupby('Year')['Votes'].mean().sort_values(ascending=False)

sns.barplot(x='Year',y='Votes',data=df1)
plt.title("Votes by Year")
plt.show()

# %% [markdown]
# ## In which year there was the highest average revenue?

# %%
df1.columns

df1.groupby('Year')['Revenue (Millions)'].mean().sort_values(ascending=False)
sns.barplot(x='Year',y='Revenue (Millions)',data=df1)
plt.title("Revenue by Year")
plt.show()

# %% [markdown]
# ## Average Rating for Each Director

# %%
df1.groupby('Director')['Rating'].mean().sort_values(ascending=False)#descending order
# Out:
# Director
# Nitesh Tiwari        8.80
# Christopher Nolan    8.68
# Olivier Nakache      8.60
# Makoto Shinkai       8.60
# Aamir Khan           8.50
#                      ...
# Micheal Bafaro       3.50
# Jonathan Holbrook    3.20
# Shawn Burkett        2.70
# James Wong           2.70
# Jason Friedberg      1.90
# Name: Rating, Length: 644, dtype: float64

# %% [markdown]
# ## Top 10 Lengthy Movies Title and Runtime

# %%
df1.columns

top10_len = df1.nlargest(10,'Runtime (Minutes)')[['Title','Runtime (Minutes)']].set_index('Title')
top10_len.index


sns.barplot(x='Runtime (Minutes)',y=top10_len.index,data=top10_len)
# Out:
# <AxesSubplot:xlabel='Runtime (Minutes)', ylabel='Title'>

# %% [markdown]
# ## Number of Movies per year

# %%
df1['Year'].value_counts()

sns.countplot(x='Year',data=df1)

plt.title("Number of Movies Per Year")
plt.show()

# %% [markdown]
# ## Most Popular Movie title(Higest Revenue)

# %%
df1[df1['Revenue (Millions)'].max()==df1['Revenue (Millions)']]['Title']


#https://www.youtube.com/watch?v=Asm2_qgBK48  For IMDB Movie Data
#https://www.youtube.com/watch?v=_E3m6Ywvnj8&list=PL_1pt6K-CLoDcWw_c196kZn7aPeLdRDOU&index=21 for gui
#https://www.youtube.com/watch?v=n9YDcH-LHa4 Kmean clustering
#heart disease prediction https://www.kaggle.com/code/jillanisofttech/heart-disease-prediction-usingdifferent-techniques#Random-Fores
#Machine learing project ref codes https://github.com/PRIYANG-BHATT/Machine-Learning-Projects-Code

#Loan Status Prediction
#https://www.youtube.com/watch?v=p3-7qW_t5bw
# Out:
# 50    Star Wars: Episode VII - The Force Awakens
# Name: Title, dtype: object

# %% [markdown]
# ## Display Top 10 Highest Rated Movie Titles and Its Director

# %%
df1.columns
top10_len = df1.nlargest(10,'Rating')[['Title','Rating','Director']].set_index('Title')
top10_len
# Out:
#                        Rating           Director
# Title
# The Dark Knight           9.0  Christopher Nolan
# Inception                 8.8  Christopher Nolan
# Dangal                    8.8      Nitesh Tiwari
# Interstellar              8.6  Christopher Nolan
# Kimi no na wa             8.6     Makoto Shinkai
# The Intouchables          8.6    Olivier Nakache
# The Prestige              8.5  Christopher Nolan
# The Departed              8.5    Martin Scorsese
# The Dark Knight Rises     8.5  Christopher Nolan
# Whiplash                  8.5    Damien Chazelle

# %%
sns.barplot(x='Rating',y=top10_len.index,data=top10_len,hue='Director',dodge=False)
plt.legend(bbox_to_anchor = (1.05,1),loc=2)

# %% [markdown]
# ## Display Top 10 Highest Revenue Movie Title

# %%
df1.head(5)
# df1.nlargest(10,'Revenue (Millions)')[['Title','Revenue (Millions)']]#return 10 highest value
top_10 = df1.nlargest(10,'Revenue (Millions)')[['Title','Revenue (Millions)']].set_index('Title')
top_10

sns.barplot(x='Revenue (Millions)',y=top_10.index,data=top_10)
plt.title("Top 10 Highest Revenue Movie Titles")
plt.show()

# %% [markdown]
# ## Find Average Rating of Movies Year Wise

# %%
df1.columns


df1.groupby('Year')['Rating'].mean().sort_values(ascending=False).mean()

#Does Rating Affect the revenue?
# sns.scatterplot(x="Rating",y="Revenue (Millions)",data=df1)
# Out:
# 6.843911765709746

# %% [markdown]
# ## Classify Movies Based on Ratings [Excellent,Good and Average]

# %%
df1.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
def rating(rating):
    if rating >= 7.0:
        return "Excellent"
    elif rating >= 6.0:
        return "Good"
    else:
        return "Average"

# %%
df1['rating_cat'] = df1['Rating'].apply(rating)
df1.head(5)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %% [markdown]
# ## Count Number of Action Movies

# %%
df1.columns

df1['Genre'].dtype#object data type 


len(df1[df1['Genre'].str.contains('Action',case=False)])
# Out:
# 303

# %% [markdown]
# ## Find Unique Values From Genre

# %%
df1['Genre']
# Out:
# 0       Action,Adventure,Sci-Fi
# 1      Adventure,Mystery,Sci-Fi
# 2               Horror,Thriller
# 3       Animation,Comedy,Family
# 4      Action,Adventure,Fantasy
#                  ...
# 995         Crime,Drama,Mystery
# 996                      Horror
# 997         Drama,Music,Romance
# 998            Adventure,Comedy
# 999       Comedy,Family,Fantasy
# Name: Genre, Length: 1000, dtype: object

# %%
list1 = []
for val in df1['Genre']:
    list1.append(val.split(','))
list1
# Out:
# [['Action', 'Adventure', 'Sci-Fi'],
#  ['Adventure', 'Mystery', 'Sci-Fi'],
#  ['Horror', 'Thriller'],
#  ['Animation', 'Comedy', 'Family'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Comedy', 'Drama', 'Music'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Biography'],
#  ['Adventure', 'Drama', 'Romance'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Action', 'Comedy', 'Drama'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Thriller'],
#  ['Biography', 'Drama'],
#  ['Drama', 'Mystery', 'Sci-Fi'],
#  ['Adventure', 'Drama', 'Thriller'],
#  ['Drama'],
#  ['Crime', 'Drama', 'Horror'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Horror', 'Thriller'],
#  ['Comedy'],
# ...

# %%
one_d = []
for item in list1:
    for item1 in item:
        one_d.append(item1)
one_d
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Mystery',
#  'Sci-Fi',
#  'Horror',
#  'Thriller',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Comedy',
#  'Drama',
#  'Music',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Biography',
#  'Adventure',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Adventure',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Horror',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Comedy',
#  'Action',
#  'Adventure',
# ...

# %%
uni_list = []
for item in one_d:
    if item not in uni_list:
        uni_list.append(item)
uni_list

len(uni_list)
# Out:
# 20

# %%
from collections import Counter
Counter(one_d)
# Out:
# Counter({'Action': 303,
#          'Adventure': 259,
#          'Sci-Fi': 120,
#          'Mystery': 106,
#          'Horror': 119,
#          'Thriller': 195,
#          'Animation': 49,
#          'Comedy': 279,
#          'Family': 51,
#          'Fantasy': 101,
#          'Drama': 513,
#          'Music': 16,
#          'Biography': 81,
#          'Romance': 141,
#          'History': 29,
#          'Crime': 150,
#          'Western': 7,
#          'War': 13,
#          'Musical': 5,
#          'Sport': 18})
